# %%
import os
import re
import operator
# import simplejson
import numpy as np
import scipy.stats as scp
import pandas as pd
from lxml import objectify
from pandas import Series, DataFrame
from collections import Counter
import matplotlib.pyplot as plt

from xml.etree import ElementTree as ET


tags_xlxpath = "Tags.xlsx"
post_xlspath = "Posts.xlsx"
user_xlspath = "Users.xlsx"
cmnt_xlspath = "Comments.xlsx"
votes_xlspath = "Votes.xlsx"
badges_xlspath = "Badges.xlsx"
postlinks_path = "PostLinks.xlsx"

post_records = pd.read_excel(post_xlspath)
tags_records = pd.read_excel(tags_xlxpath, header=1)
user_records = pd.read_excel(user_xlspath, header=1)
vote_records = pd.read_excel(votes_xlspath, header=1)



# postlinks_rec = pd.read_excel(postlinks_path, header=1)
# bdges_records = pd.read_excel(badges_xlspath, header=1)
# comnt_records = pd.read_excel(cmnt_xlspath, header=1)



# Global function
def header_cleaner(strng):
    """ Clean column header for display"""
    match = re.search(r'@\w+', strng)
    if match:
        return match.group().replace('@','')
    else:
        return strng

# %% [markdown]
# ## What fraction of posts contain the 5th most popular tag?

# %%
sorted_tags[:6]
# Out:
# [('r', 7244),
#  ('regression', 5413),
#  ('time-series', 2737),
#  ('machine-learning', 2564),
#  ('probability', 2081),
#  ('hypothesis-testing', 2000)]

# %%
# Visualize table's structure and identify (tags of interest).

tags_records.columns = [header_cleaner(col) for col in tags_records.keys()]
print(tags_records.head(5))


tags_dict = pd.Series(tags_records.Count.values, index=tags_records.TagName.values).to_dict()
sorted_tags = sorted(tags_dict.items(), key=operator.itemgetter(1), reverse=True)
print("\n\n Top 5 Tags \n============\n", sorted_tags[:5])


# For length/numbers of posts. We do not care about post without tags.
total_posts = post_records.PostTypeId.count()
print("\n\nlength of posts : ", total_posts)
poptag = sorted_tags[5][1]/total_posts

print("\n\nFraction of post having 5th most popular tag:")
print("\n\n Freq. of 5th popular tag DIVIDED by Length of posts")
print("\n %s / %s = %.9f" %(sorted_tags[5][1], total_posts, poptag ))
# Out:
#    Count  ExcerptPostId  Id      TagName  WikiPostId
# 0   1342          20258   1     bayesian       20257
# 1    168          62158   2        prior       62157
# 2      6            NaN   3  elicitation         NaN
# 3    191          67815   4    normality       67814
# 4     13            NaN   5  open-source         NaN
#
#
#  Top 5 Tags
# ============
#  [('r', 7244), ('regression', 5413), ('time-series', 2737), ('machine-learning', 2564), ('probability', 2081)]
#
#
# length of posts :  91976
#
#
# Fraction of post having 5th most popular tag:
#
#
#  Freq. of 5th popular tag DIVIDED by Length of posts
#
#  2000 / 91976 = 0.021744803

# %% [markdown]
# ## How much higher is the average answer's score than the average question's?

# %%
# How much higher is the average answer's score than the average question's?
# Cleanup the post table for display
post_records.columns = [header_cleaner(col) for col in post_records.keys()]

# Sample display of a single record
post_records[:1]

print("Total of different post types \t where 1: Question \t 2: Answer\n")
print(post_records.PostTypeId.value_counts())


stk_posts = pd.DataFrame(post_records, columns=['PostTypeId', 'Score'])
questions = stk_posts[stk_posts["PostTypeId"]==1]
answers = stk_posts[stk_posts["PostTypeId"]==2]

avg_score_diff = answers.Score.mean() - questions.Score.mean()

print("\n\n Mean Answ Score - Mean Ques. Score : %.9f" %avg_score_diff)
# Out:
# Total of different post types 	 where 1: Question 	 2: Answer
#
# 2    47755
# 1    42921
# 5      640
# 4      640
# 6        9
# 3        6
# 7        5
# dtype: int64
#
#
#  Mean Answ Score - Mean Ques. Score : 0.646649100

# %% [markdown]
# ## What is the Pearson's correlation between a user's reputation and total score from posts (for valid users)?

# %%
# What is the Pearson's correlation between a user's reputation and total score from posts (for valid users)?

user_records.columns = [header_cleaner(col) for col in user_records.keys()]

user_reput = Series(user_records.Reputation.values, index = user_records.AccountId.values).to_dict()
usr_post_scr = Series(post_records.Score.values, index = post_records.OwnerUserId.values).to_dict()

# Compute total score of valid users. 
valid_users = {key:0 for (key, value) in user_reput.items()}

for (key, value) in usr_post_scr.items():
    if key in valid_users.keys():
        valid_users[key] += value


        
user_reputation = np.array([rep for rep in user_reput.values()])

valid_users_score = np.array([value for value in valid_users.values()])

# # Pearson test using scipy module
prsnr_test = scp.stats.pearsonr(user_reputation, valid_users_score)

# #
print("(p-corr, p-signf) = ", prsnr_test)

print("\nPearson corr test : %.9f" %prsnr_test[0])
# Out:
# (p-corr, p-signf) =  (0.0032314629836997276, 0.51640661691877243)
#
# Pearson corr test : 0.003231463

# %% [markdown]
# ## How many more upvotes does the average answer receive than the average question?

# %%
# How many more upvotes does the average answer receive than the average question?

vote_records.columns = [header_cleaner(key) for key in vote_records.keys()]

# Extract differnet categories of posts.
vote_categs = pd.DataFrame(vote_records, columns=['PostId', 'VoteTypeId'])
print("Vote types - \t  1: Accepted \t 2: UPvotes \t 3: DOWNvotes \t 4: Offensive \t 5: FAVorites\n")

post_categ = DataFrame(post_records, columns=['Id', 'PostTypeId'])
post_categ.columns = ['PostId', 'PostTypeId']

tot_quetn = len(post_categ[post_categ['PostTypeId'] ==1])
tot_answer = len(post_categ[post_categ['PostTypeId'] ==2])


vote_post_type = pd.merge(post_categ, vote_categs, on='PostId', how='inner', sort=True)

is_upvote = vote_post_type['VoteTypeId'] == 2

upvoted_posts = vote_post_type[is_upvote]

upvoted_ques = len(upvoted_posts[upvoted_posts['PostTypeId']==1])

upvoted_answr = len(upvoted_posts[upvoted_posts['PostTypeId']==2])

ans = upvoted_answr/tot_answer
que = upvoted_ques/tot_quetn

print("Average Upvoted Answer: %.6f " %ans)

print("Avegrage Upvoted Question %.6f " %que)

print("\nDifference: %0.9f" %(ans-que))
# Out:
# Vote types - 	  1: Accepted 	 2: UPvotes 	 3: DOWNvotes 	 4: Offensive 	 5: FAVorites
#
# Average Upvoted Answer: 3.192357
# Avegrage Upvoted Question 2.555043
#
# Difference: 0.637313835

# %% [markdown]
# ## Subimission

# %%
import os
import re
import operator
import simplejson
import numpy as np
import scipy.stats as scp
import pandas as pd
from lxml import objectify
from pandas import Series, DataFrame
from collections import Counter
import matplotlib.pyplot as plt

from xml.etree import ElementTree as ET


tags_xlxpath = "Tags.xlsx"
post_xlspath = "Posts.xlsx"
user_xlspath = "Users.xlsx"
cmnt_xlspath = "Comments.xlsx"
votes_xlspath = "Votes.xlsx"
badges_xlspath = "Badges.xlsx"
postlinks_path = "PostLinks.xlsx"

post_records = pd.read_excel(post_xlspath)
tags_records = pd.read_excel(tags_xlxpath, header=1)
user_records = pd.read_excel(user_xlspath, header=1)
vote_records = pd.read_excel(votes_xlspath, header=1)

# Global function
def header_cleaner(strng):
    """ Clean column header for display"""
    match = re.search(r'@\w+', strng)
    if match:
        return match.group().replace('@','')
    else:
        return strng

# What fraction of posts contain the 5th most popular tag?

# Visualize table's structure and identify (tags of interest).

tags_records.columns = [header_cleaner(col) for col in tags_records.keys()]
print(tags_records.head(5))


tags_dict = pd.Series(tags_records.Count.values, index=tags_records.TagName.values).to_dict()
sorted_tags = sorted(tags_dict.items(), key=operator.itemgetter(1), reverse=True)
print("\n\n Top 5 Tags \n============\n", sorted_tags[:5])


# For length/numbers of posts. We do not care about post without tags.
total_posts = post_records.PostTypeId.count()
print("\n\nlength of posts : ", total_posts)
poptag = sorted_tags[5][1]/total_posts

print("\n\nFraction of post having 5th most popular tag:")
print("\n\n Freq. of 5th popular tag DIVIDED by Length of posts")
print("\n %s / %s = %.7f" %(sorted_tags[5][1], total_posts, poptag ))



# How much higher is the average answer's score than the average question's?
# Cleanup the post table for display
post_records.columns = [header_cleaner(col) for col in post_records.keys()]

# Sample display of a single record
post_records[:1]

print("Total of different post types \t where 1: Question \t 2: Answer\n")
print(post_records.PostTypeId.value_counts())


stk_posts = pd.DataFrame(post_records, columns=['PostTypeId', 'Score'])
questions = stk_posts[stk_posts["PostTypeId"]==1]
answers = stk_posts[stk_posts["PostTypeId"]==2]

avg_score_diff = answers.Score.mean() - questions.Score.mean()

print("\n\n Mean Answ Score - Mean Ques. Score : %.7f" %avg_score_diff)


# What is the Pearson's correlation between a user's reputation and total score from posts (for valid users)?

user_records.columns = [header_cleaner(col) for col in user_records.keys()]

user_reput = Series(user_records.Reputation.values, index = user_records.AccountId.values).to_dict()
usr_post_scr = Series(post_records.Score.values, index = post_records.OwnerUserId.values).to_dict()

# Compute total score of valid users. 
valid_users = {key:0 for (key, value) in user_reput.items()}

for (key, value) in usr_post_scr.items():
    if key in valid_users.keys():
        valid_users[key] += value


        
user_reputation = np.array([rep for rep in user_reput.values()])

valid_users_score = np.array([value for value in valid_users.values()])

# # Pearson test using scipy module
prsnr_test = scp.stats.pearsonr(user_reputation, valid_users_score)

# #
print("(p-corr, p-signf) = ", prsnr_test)

print("\nPearson corr test : %.8f" %prsnr_test[0])


# How many more upvotes does the average answer receive than the average question?

vote_records.columns = [header_cleaner(key) for key in vote_records.keys()]

# Extract differnet categories of posts.
vote_categs = pd.DataFrame(vote_records, columns=['PostId', 'VoteTypeId'])
print("Vote types - \t  1: Accepted \t 2: UPvotes \t 3: DOWNvotes \t 4: Offensive \t 5: FAVorites\n")

post_categ = DataFrame(post_records, columns=['Id', 'PostTypeId'])
post_categ.columns = ['PostId', 'PostTypeId']

tot_quetn = len(post_categ[post_categ['PostTypeId'] ==1])
tot_answer = len(post_categ[post_categ['PostTypeId'] ==2])


vote_post_type = pd.merge(post_categ, vote_categs, on='PostId', how='inner', sort=True)

is_upvote = vote_post_type['VoteTypeId'] == 2

upvoted_posts = vote_post_type[is_upvote]

upvoted_ques = len(upvoted_posts[upvoted_posts['PostTypeId']==1])

upvoted_answr = len(upvoted_posts[upvoted_posts['PostTypeId']==2])

ans = upvoted_answr/tot_answer
que = upvoted_ques/tot_quetn

print("Average Upvoted Answer: %.6f " %ans)

print("Avegrage Upvoted Question %.6f " %que)

print("\nDifference: %f" %(ans-que))

# %% [markdown]
# ## WorkArea

# %%
print([header_cleaner(key) for key in post_records.keys()])
# Out:
# ['Id', 'PostTypeId', 'AcceptedAnswerId', 'CreationDate', 'Score', 'ViewCount', 'Body', 'OwnerUserId', 'LastActivityDate', 'Title', 'Tags', 'AnswerCount', 'CommentCount', 'FavoriteCount', 'LastEditorUserId', 'LastEditDate', 'CommunityOwnedDate', 'ParentId', 'ClosedDate', 'OwnerDisplayName', 'LastEditorDisplayName']

# %%
print([header_cleaner(key) for key in bdges_records.keys()])
# Out:
# ['Date', 'Id', 'Name', 'UserId']

# %%
[header_cleaner(key) for key in vote_records.keys()]
# Out:
# ['BountyAmount', 'CreationDate', 'Id', 'PostId', 'UserId', 'VoteTypeId']

# %%
print([header_cleaner(str(key)) for key in comnt_records.keys()])
# Out:
# ['CreationDate', 'Id', 'PostId', 'Score', 'Text', 'UserDisplayName', 'UserId']

# %%
print([header_cleaner(str(key)) for key in user_records.keys()])
# Out:
# ['AboutMe', 'AccountId', 'Age', 'CreationDate', 'DisplayName', 'DownVotes', 'Id', 'LastAccessDate', 'Location', 'ProfileImageUrl', 'Reputation', 'UpVotes', 'Views', 'WebsiteUrl']

# %%
print([header_cleaner(str(key)) for key in postlinks_rec.keys()])
# Out:
# ['CreationDate', 'Id', 'LinkTypeId', 'PostId', 'RelatedPostId']

# %%
post_records
# Out:
#            Id  PostTypeId  AcceptedAnswerId             CreationDate  Score  \
# 0           1           1                15  2010-07-19T19:12:12.510     23
# 1           2           1                59  2010-07-19T19:12:57.157     22
# 2           3           1                 5  2010-07-19T19:13:28.577     54
# 3           4           1               135  2010-07-19T19:13:31.617     13
# 4           5           2               NaN  2010-07-19T19:14:43.050     81
# 5           6           1               NaN  2010-07-19T19:14:44.080    152
# 6           7           1                18  2010-07-19T19:15:59.303     76
# 7           8           1               NaN  2010-07-19T19:16:21.737      0
# 8           9           2               NaN  2010-07-19T19:16:27.553     13
# 9          10           1              1887  2010-07-19T19:17:47.537     23
# 10         11           1              1201  2010-07-19T19:18:30.810      2
# 11         12           2               NaN  2010-07-19T19:18:41.370     20
# 12         13           2               NaN  2010-07-19T19:18:56.800     14
# 13         14           2               NaN  2010-07-19T19:19:03.990      5
# 14         15           2               NaN  2010-07-19T19:19:46.160     13
# 15         16           2               NaN  2010-07-19T19:22:31.190     16
# 16         17           1                29  2010-07-19T19:24:12.187      9
# 7            288  <p>Sorry, but the emptyness was a bit overwhel...
# 8            NaN  <p><a href="http://incanter.org/">Incanter</a>...
# 9          21925  <p>Many studies in the social sciences use Lik...
# 10           224  <p>Is there a good, modern treatment covering ...
# 11           NaN  <p>See my response to <a href="http://stackove...
# 12           NaN  <p>Machine Learning seems to have its basis in...
# 13           NaN  <p>I second that Jay. Why is R valuable? Here'...
# 14           NaN  <p>John Cook gives some interesting recommenda...
# 15           NaN  <p>Two projects spring to mind:</p>\n\n<ol>\n<...
# 16          1261  <p>I have four competing models which I use to...
# 17           NaN  <p>Also see the UCI machine learning Data Repo...
# 18           NaN  <p><a href="http://www.gapminder.org/data/">Ga...
# 19           NaN  <p>The assumption of normality assumes your da...
# 20           184  <p>What are some of the ways to forecast demog...
# 21         21916  <p>How would you describe in plain English the...
# 22          7694  <p>How can I find the PDF (probability density...
# 23           NaN  <p>For doing a variety of MCMC tasks in Python...
# 24          2095  <p>What modern tools (Windows-based) do you su...
# 25          3476  <p>What is a standard deviation, how is it cal...
# 26           NaN  <p><a href="http://mathforum.org/workshops/sum...
# 27           NaN  <p><a href="http://www.gnu.org/software/gsl/" ...
# 28           NaN  <p>Contingency table (chi-square). Also Logist...
# 29           705  <p>Which methods are used for testing random v...
# ...          ...                                                ...
# 91946        NaN  <p>First, let's try to simulate some data with...
# 91947         18  <p>In the game of Bridge, 52 cards are distrub...
# 91948          3  <p>How do we specify negative costs in rpart? ...
# 91949          9  <p>If one is conducting a survey in which all ...
# 91950         16  <p>For example, I was looking at <a href="http...
# 91951        NaN  <p>I have strong reservations about whether me...
# 91952        NaN  <p>If all the null hypotheses were true, 5% of...
# 91953         49  <p>I have a methodological question, and there...
# 91954         15  <p>I'm a beginner in statistics and I have to ...
# 91955        NaN  <p>I've personally been asking this question f...
# 91956         15  <p>Are there any formulae for the quantiles of...
# 91957         40  <p>Is Student's t test a Wald test?</p>\n\n<p>...
# 91958         12  <p>Given the biometric match scores, I am requ...
# 91959        NaN  <p>Theoretical insight, institutional knowledg...
# 91960        NaN  <p>I think I got a very simple answer.</p>\n\n...
# 91961         11  <p>I'm trying to find the most similar sample ...
# 91962        NaN  <blockquote>\n  <p>Is there some approach to u...
# 91963         17  <p>Does any standard statistical software like...
# 91964         97  <p>Jon and Frank ordered 2 footlong sandwiches...
# 91965        NaN  <p>You need to multiply the probabilities with...
# 91966        NaN  <p>Line up the four sandwiches in a row where ...
# 91967         13  <p>im analyzing an article for my studies with...
# 91968         19  <p>I am trying to estimate the school effects ...
# 91969        NaN  <p>If prior to running the xtreg command you h...
# 91970        NaN  <p>Yes, the <a href="http://cran.r-project.org...
# 91971        NaN  <p>This grew too long for a comment, but I thi...
# 91972          9  <p>Assume a classification problem where there...
# 91973          5  <p>My goal is to create a formula that can giv...
# 91974        NaN  <p>As a practical answer to the real questions...
# 91975        NaN  <p>Decision trees are notoriously <strong>unst...
#
#        OwnerUserId         LastActivityDate  \
# 0                8  2010-09-15T21:08:26.077
# 1               24  2012-11-12T09:21:54.993
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                        Forecasting demographic census
# 21     Bayesian and frequentist reasoning in plain En...
# 22                         Finding the PDF given the CDF
# 23                                                   NaN
# 24              Tools for modeling financial time series
# 25                         What is a standard deviation?
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29          Testing random variate generation algorithms
# ...                                                  ...
# 91946                                                NaN
# 91947  Please help me interpret this goodness of fit ...
# 91948  Specifying negative costs (benefits) in rpart'...
# 91949               Sampling frame of a voluntary survey
# 91950  Is there a way to estimate the distribution fr...
# 91951                                                NaN
# 91952                                                NaN
# 91953  Adjust for everything you have in propensity s...
# 91954  How to interpret glmer results (variance, corr...
# 91955                                                NaN
# 91956  Quantiles of a compound gamma/negative binomia...
# 91957                   Is Student's t test a Wald test?
# 91958            Plotting of density estimates in matlab
# 91959                                                NaN
# 91960                                                NaN
# 91961          In search of a proper similarity function
# 91962                                                NaN
# 91963                     Missing data analysis software
# 91964  How to add odds? (or how I got the wrong sandw...
# 91965                                                NaN
# 91966                                                NaN
# 91967                                 Poisson regression
# 91968  Estimation of school effects using xtmixed (in...
# 91969                                                NaN
# 91970                                                NaN
# 91971                                                NaN
# 91972  Detecting a consistent pattern in a dataset vi...
# 91973  How to project video viewcount based on histor...
# 91974                                                NaN
# 91975                                                NaN
#
#                ...          AnswerCount  CommentCount  FavoriteCount  \
# 0              ...                    5             1             14
# 1              ...                    7             1              8
# 2              ...                   19             4             36
# 3              ...                    5             2              2
# 4              ...                  NaN             3            NaN
# 5              ...                   15             5            137
# 6              ...                   24             3             79
# 7              ...                    1             2            NaN
# 8              ...                  NaN             3            NaN
# 9              ...                    4             4             12
# 10             ...                    1             2              1
# 11             ...                  NaN             1            NaN
# 12             ...                  NaN             4            NaN
# 13             ...                  NaN             1            NaN
# 14             ...                  NaN             0            NaN
# 15             ...                  NaN             3            NaN
# 16             ...                    1             0              1
# 17             ...                  NaN             1            NaN
# 18             ...                  NaN             0            NaN
# 19             ...                  NaN             2            NaN
# 20             ...                    1             1              1
# 21             ...                   15             1             67
# 22             ...                    2             1              2
# 23             ...                  NaN             0            NaN
# 24             ...                    7             4              5
# 25             ...                    8            14              7
# 26             ...                  NaN             0            NaN
# 27             ...                  NaN             0            NaN
# 28             ...                  NaN             0            NaN
# 29             ...                    8             2              7
# ...            ...                  ...           ...            ...
# 91946          ...                  NaN             0            NaN
# 91947          ...                    1             3            NaN
# 91948          ...                    0             0            NaN
# 91949          ...                    0             0            NaN
# 91950          ...                    1             0            NaN
# 91951          ...                  NaN             0            NaN
# 91952          ...                  NaN             0            NaN
# 91953          ...                    2             0            NaN
# 91954          ...                    0             0            NaN
# 91955          ...                  NaN             0            NaN
# 91956          ...                    1             0            NaN
# 91957          ...                    0             4            NaN
# 91958          ...                    0             1            NaN
# 91959          ...                  NaN             0            NaN
# 91960          ...                  NaN             0            NaN
# 91961          ...                    0             3            NaN
# 91962          ...                  NaN             1            NaN
# 91963          ...                    1             0              1
# 91964          ...                    3             0            NaN
# 91965          ...                  NaN             0            NaN
# 91966          ...                  NaN             0            NaN
# 91967          ...                    0             2            NaN
# 91968          ...                    1             0            NaN
# 91970               NaN                     NaT                     NaT
# 91971               805 2014-09-14 02:05:41.233                     NaT
# 91972               NaN                     NaT                     NaT
# 91973              7290 2014-09-14 01:40:55.160                     NaT
# 91974               805 2014-09-14 02:54:13.120                     NaT
# 91975               NaN                     NaT                     NaT
#
#       ParentId               ClosedDate OwnerDisplayName LastEditorDisplayName
# 0          NaN                      NaN              NaN                   NaN
# 1          NaN                      NaN              NaN                   NaN
# 2          NaN                      NaN              NaN                   NaN
# 3          NaN                      NaN              NaN                   NaN
# 4            3                      NaN              NaN                   NaN
# 5          NaN                      NaN              NaN                   NaN
# 6          NaN                      NaN              NaN                   NaN
# 7          NaN  2010-07-19T20:19:46.577              NaN                   NaN
# 8            3                      NaN              NaN                   NaN
# 9          NaN                      NaN              NaN                   NaN
# 10         NaN                      NaN              NaN                   NaN
# 11           7                      NaN              NaN                   NaN
# 12           6                      NaN              NaN                   NaN
# 13           3                      NaN              NaN                   NaN
# 14           1                      NaN              NaN                   NaN
# 15           3                      NaN              NaN                   NaN
# 16         NaN                      NaN           user28                   NaN
# 17           7                      NaN              NaN                   NaN
# 18           7                      NaN              NaN                   NaN
# 19           2                      NaN              NaN                   NaN
# 20         NaN                      NaN              NaN                   NaN
# 21         NaN                      NaN              NaN                   NaN
# 22         NaN                      NaN              NaN                   NaN
# 23           3                      NaN              NaN                   NaN
# 24         NaN                      NaN              NaN                   NaN
# 25         NaN                      NaN              NaN                   NaN
# 26           7                      NaN              NaN                   NaN
# 27           3                      NaN           user28                   NaN
# 28          17                      NaN              NaN                   NaN
# 29         NaN                      NaN              NaN                   NaN
# ...        ...                      ...              ...                   ...
# 91946   113980                      NaN              NaN                   NaN
# 91947      NaN                      NaN              NaN                   NaN
# 91948      NaN                      NaN              NaN                   NaN
# 91949      NaN                      NaN              NaN                   NaN
# 91950      NaN                      NaN              NaN                   NaN
# 91951   115352                      NaN              NaN                   NaN
# 91952   115348                      NaN              NaN                   NaN
# 91953      NaN                      NaN              NaN                   NaN
# 91954      NaN                      NaN              NaN                   NaN
# 91955   115355                      NaN              NaN                   NaN
# 91956      NaN                      NaN              NaN                   NaN
# 91957      NaN                      NaN              NaN                   NaN
# 91958      NaN                      NaN              NaN                   NaN
# 91959   115355                      NaN              NaN                   NaN
# 91960   115279                      NaN              NaN                   NaN
# 91961      NaN                      NaN              NaN                   NaN
# 91962   108430                      NaN              NaN                   NaN
# 91963      NaN                      NaN              NaN                   NaN
# 91964      NaN                      NaN              NaN                   NaN
# 91965   115367                      NaN              NaN                   NaN
# 91966   115367                      NaN              NaN                   NaN
# 91967      NaN                      NaN              NaN                   NaN
# 91968      NaN                      NaN              NaN                   NaN
# 91969   115371                      NaN              NaN                   NaN
# 91970   115366                      NaN              NaN                   NaN
# 91971   115367                      NaN              NaN                   NaN
# 91972      NaN                      NaN              NaN                   NaN
# 91973      NaN                      NaN              NaN                   NaN
# 91974   115358                      NaN              NaN                   NaN
# 91975   115375                      NaN              NaN                   NaN
#
# [91976 rows x 21 columns]
