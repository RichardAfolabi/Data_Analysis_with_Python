# %% [markdown]
# # Challenge Question #3 - Project Proposal

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
matplotlib.style.use('ggplot')
from IPython.display import Image

pd.set_option('notebook_repr_html', True)
pd.set_option('display.mpl_style', 'default') 

import seaborn as sns
sns.set_context("talk")
sns.set_style("darkgrid")
pd.set_option('precision', 10)
print('done!')
# Out:
# done!

# %% [markdown]
# ### - Dataset description & source:

# %% [markdown]
# https://aws.amazon.com/datasets/labor-statistics-databases/?tag=datasets%23keywords%23economics
#
# - Statistics on Inflation & Prices, Employment, Unemployment, Pay & Benefits, Spending & Time Use, Productivity, Workplace Injuries, International Comparisons, Employment Projections, and Regional Resources

# %% [markdown]
# ### Project Description

# %%
Image(filename="img/quote.png", width=500)

# %%
Image(filename="img/title.png", width=500)

# %%
Image(filename="img/benefits.png", width=500)

# %%
Image(filename="img/modeling.png", width=500)

# %% [markdown]
# ##

# %%
col_names = {'age_code':'object', 'los_code':'object', 'race':'object'}
data_url = '../_datasets_downloads/occupational_injuries/cd/cd.series.gz'

injuries = pd.read_table(data_url, dtype=col_names, compression='gzip')

print(injuries.shape)

injuries.head()
# Out:
# (392589, 19)
# /Users/RichardAfolabi/anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2871: DtypeWarning: Columns (1,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            series_id category_code  datatype_code case_code age_code los_code  \
# 0  CDU00000033                   0              3         3      NaN      NaN
# 1  CDU0000003E                   0              3         E      NaN      NaN
# 2  CDU0000003N                   0              3         N      NaN      NaN
# 3  CDU0000003P                   0              3         P      NaN      NaN
# 4  CDU0000003S                   0              3         S      NaN      NaN
#
#   race_code gender_code pob_code event_code source_code occupation_code  \
# 0       NaN         NaN      NaN        NaN         NaN             NaN
# 1       NaN         NaN      NaN       0000         NaN             NaN
# ...

# %%
pd.read_table('https://s3.amazonaws.com/labour-statistics-dataset/cd/cd.race.gz', compression='gzip')
# Out:
#   race_code                          race_text
# 0      0000                          All races
# 1      1XXX                White, non-Hispanic
# 2      2XXX                Black, non-Hispanic
# 3      3XXX                           Hispanic
# 4      4XXX          Asian or Pacific Islander
# 5      5XXX  American Indian or Alaskan Native
# 6      NRXX                       Not reported

# %%
pd.read_table('https://s3.amazonaws.com/labour-statistics-dataset/cd/cd.age.gz', compression='gzip')
# Out:
#   age_code     age_text
# 0     0000  All workers
# 1     14XX     Under 14
# 2     15XX      14 - 15
# 3     19XX      16 - 19
# 4     24XX      20 - 24
# 5     34XX      25 - 34
# 6     44XX      35 - 44
# 7     54XX      45 - 54
# 8     64XX      55 - 64
# 9     65XX  65 and over

# %%
pd.read_table('https://s3.amazonaws.com/labour-statistics-dataset/cd/cd.los.gz', compression='gzip')
# Out:
#   los_code            los_text
# 0     0000         All workers
# 1     1XXX  Less than 3 months
# 2     2XXX       3 - 11 months
# 3     3XXX         1 - 5 years
# 4     4XXX   More than 5 years
# 5     NRXX        Not reported
