# %%
"""
Demo using fontdict to control style of text and labels.
"""
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


font = {'family' : 'serif',
        'color'  : 'darkred',
        'weight' : 'normal',
        'size'   : 16,
        }

x = np.linspace(0.0, 5.0, 100)
y = np.cos(2 * np.pi * x) * np.exp(-x)

plt.plot(x, y, '-b')
plt.title('Damped exponential decay', fontdict=font)
plt.text(2, 0.65, r'$\cos(2 \pi t) \exp(-t)$', fontdict=font)
plt.xlabel('time (s)', fontdict=font)
plt.ylabel('voltage (mV)', fontdict=font)

# Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
plt.show()

# %% [markdown]
# ## Scatterplot

# %%
# marker size/color set with data


x = np.random.rand(200)
y = np.random.rand(200)

size = np.random.rand(200) * 30
color = np.random.rand(200)

plt.scatter(x,y,size,color)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1067b8680>

# %% [markdown]
# ## Image Manipulations

# %%
from scipy.misc import lena
from matplotlib import cm

img = lena()

plt.subplot(2,2,1)
plt.imshow(img, extent=[-25, 25, -25, 25], cmap=cm.copper)
plt.subplot(2,2,2)
plt.imshow(img, extent=[-25, 25, -25, 25], cmap=cm.bone)
plt.subplot(2,2,3)
plt.imshow(img, extent=[-25, 25, -25, 25], cmap=cm.BuPu)
plt.subplot(2,2,4)
plt.imshow(img, extent=[-25, 25, -25, 25], cmap=cm.Reds)

# %% [markdown]
# ## Histgrams

# %%
plt.hist(np.random.randn(1000),30)
# Out:
# (array([   3.,    2.,    0.,    4.,    6.,    9.,   26.,   28.,   43.,
#           59.,   92.,   89.,   81.,   88.,  102.,   87.,   76.,   60.,
#           50.,   34.,   29.,   16.,    7.,    4.,    3.,    0.,    1.,
#            0.,    0.,    1.]),
#  array([-3.35422475, -3.11051386, -2.86680297, -2.62309208, -2.37938119,
#         -2.1356703 , -1.89195941, -1.64824852, -1.40453763, -1.16082674,
#         -0.91711585, -0.67340496, -0.42969408, -0.18598319,  0.0577277 ,
#          0.30143859,  0.54514948,  0.78886037,  1.03257126,  1.27628215,
#          1.51999304,  1.76370393,  2.00741482,  2.25112571,  2.4948366 ,
#          2.73854749,  2.98225837,  3.22596926,  3.46968015,  3.71339104,
#          3.95710193]),
#  <a list of 30 Patch objects>)

# %% [markdown]
# ## 3D Visualization - Surface Plot

# %%
from mpl_toolkits.mplot3d import Axes3D


x,y = np.mgrid[-5:5:35j, 0:10:35j]
z = x * np.sin(x) * np.cos(0.25*y)

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_surface(x, y, z, rstride=1, cstride=1, cmap=cm.jet)

plt.xlabel('x'); plt.ylabel('y')



t = np.linspace(0,30,1000)
x, y, z = [t*np.cos(t), t*np.sin(t), t]

fig = plt.figure()

ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.xlabel('x'); plt.ylabel('y')
